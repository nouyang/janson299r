# %%
include("testRRTstar.jl")
main()
# Out:
#  - pathfound true -
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="600" viewBox="0 0 600 600">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="600"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 0,600 600,600 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="60" width="421" height="421"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 28.9273,575.813 580.315,575.813 580.315,31.4961 28.9273,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="31" width="552" height="545"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.8763,567.649 74.8763,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   97.8507,567.649 97.8507,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   120.825,567.649 120.825,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   143.8,567.649 143.8,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   166.774,567.649 166.774,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   189.749,567.649 189.749,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.723,567.649 212.723,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   235.698,567.649 235.698,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   258.672,567.649 258.672,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   281.647,567.649 281.647,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   304.621,567.649 304.621,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   327.596,567.649 327.596,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   350.57,567.649 350.57,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   373.545,567.649 373.545,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.519,567.649 396.519,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   419.494,567.649 419.494,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   442.468,567.649 442.468,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   465.443,567.649 465.443,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.417,567.649 488.417,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   511.392,567.649 511.392,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   534.366,567.649 534.366,39.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,530.454 572.044,530.454
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,507.774 572.044,507.774
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,485.094 572.044,485.094
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,462.414 572.044,462.414
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,439.734 572.044,439.734
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,417.054 572.044,417.054
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,394.374 572.044,394.374
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,371.694 572.044,371.694
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,349.015 572.044,349.015
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,326.335 572.044,326.335
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,303.655 572.044,303.655
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,280.975 572.044,280.975
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,258.295 572.044,258.295
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,235.615 572.044,235.615
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,212.935 572.044,212.935
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,190.255 572.044,190.255
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,167.575 572.044,167.575
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,144.896 572.044,144.896
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,122.216 572.044,122.216
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,99.5357 572.044,99.5357
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.1981,76.8558 572.044,76.8558
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   28.9273,575.813 580.315,575.813
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   28.9273,575.813 28.9273,31.4961
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.8763,575.813 74.8763,567.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   97.8507

# %%
include("testRRT.jl")
main()
# Out:
# MethodError: no method matching algT.TreeNode(::Int64, ::GeometryTypes.Point{2,Float64})
#
# Stacktrace:
#  [1] rrtPlan(::algT.Room, ::algT.AlgParameters, ::GeometryTypes.Point{2,Float64}, ::GeometryTypes.Point{2,Float64}, ::Array{GeometryTypes.HyperRectangle,1}) at /home/nrw/Documents/299r/janson299r/wk11/RRT.jl:347
#  [2] main() at /home/nrw/Documents/299r/janson299r/wk11/testRRT.jl:48
#  [3] include_string(::String, ::String) at ./loading.jl:522

# %%
a= Point(1,2)
b = Point(4,5)
min_euclidean(Vec(a),Vec(b))

# %%
mutable struct edge
    startID
    endID
end


mutable struct gnode
id
parentid
state
cost
#tnode() = (a= new(); a.state = -1; a.cost = 99999)
gnode() = new()
end

a = edge(1,2)
b = edge(2,3)
c = edge(6,5)

foo = [a, b, c]
foo = Vector{edge}()
push!(foo, a, b,c)

d = edge(1,1)
e = edge(6,5)


Base.isequal(q1::edge, q2::edge) = q1.startID == q2.startID && q1.endID == q2.endID
#Base.==(q1::edge, q2::edge) = q1.startID == q2.startID && q1.endID == q2.endID


findin(foo, [e])


i = findfirst(foo) do y
    y.startID == e.startID && y.endID == e.endID
end

deleteat!(foo, i)


foo
for i in foo
    i.startID = 1
end

foo


a = gnode(); a.id = 2; a.parentid =3;
a

typeof(a)

# %% [markdown]
# mutable struct Node2
# id
# cost
# end
#
#
# a= Node2(1,2)
# a.id
#
#
# ```
# findfirst(y -> y > 7, x)v
#
# myfilter(y) = y > 2
# milter = y-> Y > 2
#
# (y -> y > 2).(x)
#
#
# first argument by convention
#
# findfirst(x) do y
#  z = y+2
#  z > 2
# end
#
# returns 0 if not work
#
# ```
